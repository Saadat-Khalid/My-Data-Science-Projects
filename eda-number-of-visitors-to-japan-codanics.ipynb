# %% [markdown]
# <a href="https://www.kaggle.com/code/saadatkhalid/eda-number-of-visitors-to-japan-codanics?scriptVersionId=150403491" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# <div style="background-color: #FF7F50; color: #FFFFFF; padding: 10px; font-size: 24px; font-weight: bold; text-align: center; border-radius: 5px;">Project Title: EDA - Number of visitors to Japan</div>
#
# # About Dataset
# year: 2023\
# data: government statistics\
# __Dataset is taken from [Kaggle](https://www.kaggle.com/datasets/risakashiwabara/japannumber-of-visitors-to-japan/data)__

# %% [markdown]
# ___

# %% [markdown]
# ### Author: *Saadat Khalid Awan*
# **Email:** *me.saadi96@gmail.com*\
# **Website:** *https://thesaadat.blogspot.com/*
#
# ## 🌐 Let's Connect:
# [![Facebook](https://img.shields.io/badge/Facebook-%231877F2.svg?logo=Facebook&logoColor=white)](https://facebook.com/Saadat.Khalid.Awan) [![Instagram](https://img.shields.io/badge/Instagram-%23E4405F.svg?logo=Instagram&logoColor=white)](https://instagram.com/saadii_awan66) [![LinkedIn](https://img.shields.io/badge/LinkedIn-%230077B5.svg?logo=linkedin&logoColor=white)](https://linkedin.com/in/saadatawan) [![Medium](https://img.shields.io/badge/Medium-12100E?logo=medium&logoColor=white)](https://medium.com/@@me.saadat) [![Pinterest](https://img.shields.io/badge/Pinterest-%23E60023.svg?logo=Pinterest&logoColor=white)](https://pinterest.com/its_saadatkhalid) [![Quora](https://img.shields.io/badge/Quora-%23B92B27.svg?logo=Quora&logoColor=white)](https://quora.com/profile/Saadat-Khalid-Awan) [![TikTok](https://img.shields.io/badge/TikTok-%23000000.svg?logo=TikTok&logoColor=white)](https://tiktok.com/@saadat.awan) [![Twitter](https://img.shields.io/badge/Twitter-%231DA1F2.svg?logo=Twitter&logoColor=white)](https://twitter.com/saadat_96) [![YouTube](https://img.shields.io/badge/YouTube-%23FF0000.svg?logo=YouTube&logoColor=white)](https://youtube.com/@saadatkhalidawan) [![Github](https://img.shields.io/badge/Github-%23FF0000.svg?logo=Github&logoColor=Black)](https://github.com/Saadat-Khalid/)

# %% [markdown]
# # 1. Importing Libraries

# %%
# libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %% [markdown]
# ### Important Step: To display all values in a pandas DataFrame

# %% [markdown]
# # 2. Data Loading

# %% [markdown]
#  ↪ Load the csv file with the pandas
#
#  ↪ creating the dataframe and understanding the data present in the dataset using pandas

# %% [markdown]
# __There are two `datasets` one is `"Number of foreign visitors to Japan by month"` and other one is `"Number of foreign visitors to Japan by year"`__
#
# - First I'll Check the `by month` and after `by year`

# %% [markdown]
# ### Number of foreign visitors to Japan by month

# %%
df = pd.read_csv('/kaggle/input/japannumber-of-visitors-to-japan/Number of foreign visitors to Japan by month_ .csv')

# %% [markdown]
# - Viewing the first five Rows of the data

# %%
df.head()
# Out:
#   Country/Area Month   Year  Visitor
# 0  Afghanistan   Jan.  2017      233
# 1  Afghanistan   Feb.  2017      196
# 2  Afghanistan   Mar.  2017      192
# 3  Afghanistan   Apr.  2017      259
# 4  Afghanistan    May  2017      228

# %% [markdown]
# - Viewing the Columns present in the dataset

# %%
df.columns
# Out:
# Index(['Country/Area', 'Month ', 'Year', 'Visitor'], dtype='object')

# %% [markdown]
# * There are 4 columns in this dataset
#   * `Country/Area`, `Month`, `Year`, `Visitor`

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17052 entries, 0 to 17051
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Country/Area  17052 non-null  object
#  1   Month         17052 non-null  object
#  2   Year          17052 non-null  int64
#  3   Visitor       17052 non-null  int64
# dtypes: int64(2), object(2)
# memory usage: 533.0+ KB

# %% [markdown]
# - The total number of `Rows` are 17052
# - The total number of `Columns` are 4
# - `Country/Area` and `Month` columns are `object` dtype
# - `Year` and `Visitors` columns are `int64` dtype

# %% [markdown]
# ### Number of foreign visitors to Japan by Year

# %%
df_year = pd.read_csv('/kaggle/input/japannumber-of-visitors-to-japan/Number of foreign visitors to Japan by year_ .csv')

# %% [markdown]
# - Viewing the first five Rows of the data

# %%
df_year.head()
# Out:
#    Year  Visitor Arrivals
# 0  1964            352832
# 1  1965            366649
# 2  1966            432937
# 3  1967            476771
# 4  1968            519004

# %% [markdown]
# - Viewing the Columns present in the dataset

# %%
df_year.columns
# Out:
# Index(['Year', 'Visitor Arrivals'], dtype='object')

# %% [markdown]
# * There are 2 columns in this dataset
#   * `Year`, `Visitors Arrivals`

# %%
df_year.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60 entries, 0 to 59
# Data columns (total 2 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Year              60 non-null     int64
#  1   Visitor Arrivals  60 non-null     int64
# dtypes: int64(2)
# memory usage: 1.1 KB

# %% [markdown]
# - The total number of `Rows` are 60
# - The total number of `Columns` are 2
# - `Year` and `Visitor Arrivals` columns are `int64` dtype

# %% [markdown]
# ### Checking for Null/Missing Values in the both Datasets

# %%
df.isnull().sum() # for vistors by months
# Out:
# Country/Area    0
# Month           0
# Year            0
# Visitor         0
# dtype: int64

# %%
df_year.isnull().sum() # for vistors by year
# Out:
# Year                0
# Visitor Arrivals    0
# dtype: int64

# %% [markdown]
# - The Dataset contains no missing/null values.

# %% [markdown]
# ## How many Countries are there in the dataset?

# %%
df['Country/Area'].nunique()
# Out:
# 203

# %%
df['Country/Area'].value_counts().sort_values(ascending=True)
# Out:
# Country/Area
# Afghanistan       84
# Brunei            84
# Algeria           84
# Andorra           84
# Angola            84
#                   ..
# Venezuela         84
# Vietnam           84
# Yemen             84
# United Kingdom    84
# Zimbabwe          84
# Name: count, Length: 203, dtype: int64

# %% [markdown]
# ## Obervation:
# ___
#
# There are total `203` countries in the dataset. Where each country count is `84`. If we multiple `84*203` we get total number of rows `17,052`

# %% [markdown]
# ## Which Country visits to Japan more each Year?

# %%
df.columns
# Out:
# Index(['Country/Area', 'Month ', 'Year', 'Visitor'], dtype='object')

# %%
top_countries_by_year = df.groupby(['Year', 'Country/Area'])['Visitor']
top_countries_by_year.sum().groupby('Year').nlargest(5)
# Out:
# Year  Year  Country/Area
# 2017  2017  China            7355818
#             South Korea      7140438
#             Taiwan           4564053
#             Hong Kong        2231568
#             United States    1374964
# 2018  2018  China            8380034
#             South Korea      7538952
#             Taiwan           4757258
#             Hong Kong        2207804
#             United States    1526407
# 2019  2019  China            9594394
#             South Korea      5584597
#             Taiwan           4890602
#             Hong Kong        2290792
#             United States    1723861
# 2020  2020  China            1069256
#             Taiwan            694476
#             South Korea       487939
#             Hong Kong         346020
#             Thailand          219830
# 2021  2021  China              42239
#             Vietnam            26586
#             United States      20026
#             South Korea        18947
# ...

# %%
top_countries_by_year = df.groupby(['Year', 'Country/Area'])['Visitor'].sum().reset_index()
top_countries_by_year = top_countries_by_year.groupby('Year').apply(lambda x: x.nlargest(10, 'Visitor')).reset_index(drop=True)

fig = px.bar(top_countries_by_year, x='Year', y='Visitor', color='Country/Area', title='Top 10 Countries by Visitor Count')
fig.show()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.25.2.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# ...

# %% [markdown]
# ## Observation:
# ___

# %% [markdown]
# - China has consistently been the largest source of visitors to Japan from 2017 to 2023, except for a significant decrease in 2021.
# - South Korea and Taiwan are the second and third most common countries of origin for visitors to Japan, following China.
# - Hong Kong and the United States are also among the top five countries of origin for visitors to Japan.
# - The number of visitors from South Korea to Japan has shown a significant increase over the years.
# - Taiwan has had a stable number of visitors to Japan, with a slight increase in 2023.
# - The United States has experienced a gradual increase in visitor count to Japan, reaching its peak in 2023.
# - Hong Kong has shown fluctuating visitor numbers, with a notable decrease in 2023.
# - Other countries such as Thailand, Vietnam, and Nepal also contribute to the visitor count to Japan, but in smaller numbers compared to the top countries mentioned above.

# %% [markdown]
# ## Which Country Least Visits to Japan each Year?

# %%
lowest_countries_by_year = df.groupby(['Year', 'Country/Area'])['Visitor']
lowest_countries_by_year.sum().groupby('Year').nsmallest(10)
# Out:
# Year  Year  Country/Area
# 2017  2017  East Germany             0
#             Serbia and Montenegro    0
#             South Yemen              0
#             Unknown                  0
#             Central Africa           5
#                                     ..
# 2023  2023  Sao Tome and Principe    1
#             Equatorial Guinea        2
#             Vatican                  2
#             Guinea-Bissau            6
#             Central Africa           8
# Name: Visitor, Length: 70, dtype: int64

# %%
lowest_countries_by_year = df.groupby(['Year', 'Country/Area'])['Visitor'].sum().reset_index()
lowest_countries_by_year = lowest_countries_by_year.groupby('Year').apply(lambda x: x.nsmallest(10, 'Visitor')).reset_index(drop=True)

fig = px.bar(lowest_countries_by_year, x='Year', y='Visitor', color='Country/Area', title='Least 10 Countries by Visitor Count')
fig.show()
# Out:
# <div>                            <div id="7fb54ccc-232e-4af5-b8d8-dd36738bee22" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7fb54ccc-232e-4af5-b8d8-dd36738bee22")) {                    Plotly.newPlot(                        "7fb54ccc-232e-4af5-b8d8-dd36738bee22",                        [{"alignmentgroup":"True","hovertemplate":"Country\u002fArea=East Germany\u003cbr\u003eYear=%{x}\u003cbr\u003eVisitor=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"East Germany","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"East Germany","offsetgroup":"East Germany","orientation":"v","showlegend":true,"textposition":"auto","x":[2017,2018,2019,2020,2021,2022,2023],"xaxis":"x","y":[0,0,0,0,0,0,0],"yaxis":"y","type":"bar"},{"alignmentgrou
# ...

# %% [markdown]
# ## Observation:
# ____

# %% [markdown]
# - East Germany, Serbia and Montenegro, South Yemen, and Unknown had no recorded visitors to Japan from 2017 to 2023, indicating minimal or no tourist exchange with Japan during this period.
# - Central Africa, Equatorial Guinea, Sao Tome and Principe, and Vatican had consistently low visitor numbers to Japan, suggesting a relatively small number of tourists from these countries.
# - Guinea-Bissau showed a small but increasing interest in visiting Japan, with visitor counts ranging from 13 in 2017 to 30 in 2019 and 6 in 2023.
# - North Korea had a small number of visitors to Japan, with counts ranging from 13 in 2018 and 2019 to 0 in subsequent years, suggesting potential travel restrictions or limitations.
# - Saint Vincent, Micronesia, Belize, Nauru, San Marino, and Saint Kitts and Nevis recorded a small number of visitors to Japan in specific years, indicating limited tourist exchange with Japan.

# %% [markdown]
# ## How many Visitors Arrival Over Year?

# %%
df_year.groupby('Year')['Visitor Arrivals'].sum()
# Out:
# Year
# 1964      352832
# 1965      366649
# 1966      432937
# 1967      476771
# 1968      519004
# 1969      608744
# 1970      854419
# 1971      660715
# 1972      723744
# 1973      784691
# 1974      764246
# 1975      811672
# 1976      914772
# 1977     1028140
# 1978     1038875
# 1979     1112606
# 1980     1316632
# 1981     1583043
# 1982     1793164
# 1983     1968461
# 1984     2110346
# 1985     2327047
# 1986     2061526
# 1987     2154864
# 1988     2355412
# 1989     2835064
# 1990     3235860
# 1991     3532651
# 1992     3581540
# 1993     3410447
# 1994     3468055
# 1995     3345274
# 1996     3837113
# 1997     4218208
# 1998     4106057
# 1999     4437863
# 2000     4757146
# 2001     4771555
# 2002     5238963
# 2003     5211725
# 2004     6137905
# 2005     6727926
# 2006     7334077
# 2007     8346969
# 2008     8350835
# 2009     6789658
# 2010     8611175
# 2011     6218752
# 2012     8358105
# 2013    10363918
# 2014    13413473
# 2015    19737409
# ...

# %%
fig = px.scatter(df_year, x='Year', y='Visitor Arrivals', size = 'Visitor Arrivals', color='Visitor Arrivals' ,title='Visitor Arrivals to Japan Over Time')
fig.update_layout(xaxis_title='Year', yaxis_title='Visitor Arrivals')

# Show the plot
fig.show()
# Out:
# <div>                            <div id="4ab73f5b-dfff-4b46-9951-e971ea4f83c5" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4ab73f5b-dfff-4b46-9951-e971ea4f83c5")) {                    Plotly.newPlot(                        "4ab73f5b-dfff-4b46-9951-e971ea4f83c5",                        [{"hovertemplate":"Year=%{x}\u003cbr\u003eVisitor Arrivals=%{marker.color}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":[352832,366649,432937,476771,519004,608744,854419,660715,723744,784691,764246,811672,914772,1028140,1038875,1112606,1316632,1583043,1793164,1968461,2110346,2327047,2061526,2154864,2355412,2835064,3235860,3532651,3581540,3410447,3468055,3345274,3837113,4218208,4106057,4437863,4757146,4771555,5238963,5211725,6137905,6
# ...

# %% [markdown]
# ## Observation:
# ___

# %% [markdown]
# - The number of visitor arrivals to Japan has generally increased over the years.
# - There was a significant increase starting from the 1970s, with a peak of 24 million arrivals in 2016.
# - 2017 saw a further increase to nearly 29 million arrivals.
# - In 2018 and 2019, there were over 31 million arrivals each year.
# - However, due to the COVID-19 pandemic, the number dropped to around 4 million in 2020.
# - In 2021, there were only approximately 246,000 arrivals.
# - The years 2022 and 2023 show signs of recovery with 3.8 million and 10.7 million arrivals, respectively.

# %% [markdown]
# ### The END

# %% [markdown]
# ____
# ### Author: *Saadat Khalid Awan*
# **Email:** *me.saadi96@gmail.com*\
# **Website:** *https://thesaadat.blogspot.com/*
#
# ## 🌐 Let's Connect:
# [![Facebook](https://img.shields.io/badge/Facebook-%231877F2.svg?logo=Facebook&logoColor=white)](https://facebook.com/Saadat.Khalid.Awan) [![Instagram](https://img.shields.io/badge/Instagram-%23E4405F.svg?logo=Instagram&logoColor=white)](https://instagram.com/saadii_awan66) [![LinkedIn](https://img.shields.io/badge/LinkedIn-%230077B5.svg?logo=linkedin&logoColor=white)](https://linkedin.com/in/saadatawan) [![Medium](https://img.shields.io/badge/Medium-12100E?logo=medium&logoColor=white)](https://medium.com/@@me.saadat) [![Pinterest](https://img.shields.io/badge/Pinterest-%23E60023.svg?logo=Pinterest&logoColor=white)](https://pinterest.com/its_saadatkhalid) [![Quora](https://img.shields.io/badge/Quora-%23B92B27.svg?logo=Quora&logoColor=white)](https://quora.com/profile/Saadat-Khalid-Awan) [![TikTok](https://img.shields.io/badge/TikTok-%23000000.svg?logo=TikTok&logoColor=white)](https://tiktok.com/@saadat.awan) [![Twitter](https://img.shields.io/badge/Twitter-%231DA1F2.svg?logo=Twitter&logoColor=white)](https://twitter.com/saadat_96) [![YouTube](https://img.shields.io/badge/YouTube-%23FF0000.svg?logo=YouTube&logoColor=white)](https://youtube.com/@saadatkhalidawan) [![Github](https://img.shields.io/badge/Github-%23FF0000.svg?logo=Github&logoColor=Black)](https://github.com/Saadat-Khalid/)

# %% [markdown]
# _____
